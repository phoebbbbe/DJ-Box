# %%
from pytube import YouTube
from pytube import Playlist
from pydub import AudioSegment
from bs4 import BeautifulSoup
import os
from glob import glob
import openpyxl
import numpy as np
import pandas as pd
import json
import librosa
import math
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### 列出 ID Title Duration URL

# %%
def DownloadAndExtracFeature(youtube_lists_url, mp4_path, wav_path, csv_path):
    
    # 設定參數值
    SR = 22050
    N_MELS = 20
    N_FFT = 2048
    HOP_LEN = 512
    N_CHROMA = 12
            
    # 遍歷播放清單
    video_urls = []

    for yt_list_url in youtube_lists_url:

        # 播放列表URL
        playlist_url = yt_list_url

        # 創建Playlist對象
        playlist = Playlist(yt_list_url)

        # 解析播放列表
        playlist._video_regex = r"\"url\":\"(/watch\?v=[\w-]*)"

        # 播放列表URL
        video_urls += playlist.video_urls

    # 提取每首歌曲的編號、歌名、長度、URL、擷取到的特徵
    data = {
        'title':[],
        'duration':[],
        'url':[],
        'centroid_mean':[],
        'roloff_mean':[],
        'flux_mean':[],
        'rmse_mean':[],
        'zcr_mean':[],
        'bandwidth_mean':[],
        'flatness_mean':[],
    }
    for i in range(N_MELS):
        data[f'mels_{i}_mean'] = []
    for i in range(N_CHROMA):
        data[f'chroma_{i}_mean'] = []
    
    song_id = 0
    
    # 遍歷播放列表URL
    for i, url in enumerate(video_urls):
        try:
            # 創建YouTube對象
            youtube = YouTube(url)

            # 選擇最高質量的影片流
            video_stream = youtube.streams.get_highest_resolution()

            # 下載影片
            file_name = f"{song_id}.mp4"
            video_file = video_stream.download(filename = file_name, output_path = mp4_path)

            # 儲存影片路徑
            video_paths = f"{mp4_path}/{file_name}"
            
            print(f"成功下載: {file_name}:{youtube.title}")
            
            try:
                # 將 MP4 轉為 WAV 存起來
                mp4_audio = AudioSegment.from_file(video_paths, "mp4")
                mp4_audio.export(f"{wav_path}/{song_id}.wav", format="wav")

                print(f"成功轉換: {song_id}.wav")

                dir = mp4_path
                for f in os.listdir(dir):
                    os.remove(os.path.join(dir, f))
            
                try:
                    # 擷取特徵
                    # 載入聲音資料
                    # 取得音頻資料、採樣率
                    signal, sample_rate = librosa.load(f"{wav_path}/{song_id}.wav", sr=SR)

                    # 提取質心特徵（spectral centroid）
                    centroid = librosa.feature.spectral_centroid(y=signal, sr=SR, n_fft=N_FFT, hop_length=HOP_LEN).ravel()
                    centroid_mean = centroid.mean()

                    # 提取衰減特徵（spectral rolloff）
                    roloff = librosa.feature.spectral_rolloff(y=signal, sr=SR, n_fft=N_FFT, hop_length=HOP_LEN).ravel().mean()
                    roloff_mean = roloff.mean()

                    # 提取過零率特徵（zero-crossing rate）
                    zcr = librosa.feature.zero_crossing_rate(y=signal, frame_length=N_FFT, hop_length=HOP_LEN).ravel().mean()
                    zcr_mean = zcr.mean()

                    # 提取均方根能量特徵（root mean square, RMS）
                    rmse = librosa.feature.rms(y=signal, frame_length=N_FFT, hop_length=HOP_LEN).ravel().mean()
                    rmse_mean = rmse.mean()

                    # 提取起點強度特徵（onset strength）
                    flux = librosa.onset.onset_strength(y=signal, sr=SR).ravel().mean()
                    flux_mean = flux.mean()

                    # 提取頻譜帶寬特徵（spectral bandwidth）
                    bandwidth = librosa.feature.spectral_bandwidth(y=signal, sr=SR, n_fft=N_FFT, hop_length=HOP_LEN).ravel().mean()
                    bandwidth_mean = bandwidth.mean()

                    # 提取頻譜平坦度特徵（spectral flatness）
                    flatness = librosa.feature.spectral_flatness(y=signal, n_fft=N_FFT, hop_length=HOP_LEN).ravel().mean()
                    flatness_mean = flatness.mean()

                    # 提取色度特徵（Chromagram）
                    chroma = librosa.feature.chroma_stft(y=signal, sr=SR, hop_length=HOP_LEN)

                    # 提取梅爾頻譜特徵（Mel spectrogram）
                    mels = librosa.feature.melspectrogram(y=signal, sr=SR, n_fft=N_FFT, n_mels=N_MELS, hop_length=HOP_LEN)
                    mels = librosa.power_to_db(mels)

                    data['title'].append(youtube.title)
                    data['duration'].append(youtube.length)
                    data['url'].append(url)
                    
                    data['centroid_mean'].append(centroid_mean)
                    data['roloff_mean'].append(roloff_mean)
                    data['zcr_mean'].append(zcr_mean)
                    data['rmse_mean'].append(rmse_mean)
                    data['flux_mean'].append(flux_mean)
                    data['bandwidth_mean'].append(bandwidth_mean)
                    data['flatness_mean'].append(flatness_mean)
                    for idx, v_mels in enumerate(mels):
                        data[f"mels_{idx}_mean"].append(v_mels.ravel().mean())

                    for idx, v_chroma in enumerate(chroma):
                        data[f"chroma_{idx}_mean"].append(v_chroma.ravel().mean())
                    
                    print(f"成功取得特徵: {song_id}.wav")
                        
                    song_id += 1
            
                except Exception as e:
                    print(f"取得特徵失敗: {str(e)}")
                
            except Exception as e:
                print(f"轉換失败: {str(e)}")
            
        except Exception as e:
            print(f"下載失败: {str(e)}")
       
    return data

# %%
# 設定路徑

mp4_path = "/Users/phoebe/DJ-Box_model/dataset/mp4_files"

youtube_lists_url = ["https://youtube.com/playlist?list=PLQdn7YisXz3NBAGjVjgtKlnPLj5TaO975"]
# youtube_lists_url = ["https://youtube.com/playlist?list=PLHh4zQmRdiTKHuwFPtxwp5sUcY5tV04e3",
#                      "https://youtube.com/playlist?list=PLHeL32XSCxMwKZT60Q2EtQMvq2Ock4MxT",
#                      "https://youtube.com/playlist?list=PL58yl8ZTfuDqHWTj-VaIoBiNDbKxWB-V4",
#                      "https://youtube.com/playlist?list=PLOVz_6E6CsBf1dbv4vwkzPxeShJ8uQgCR",
#                      "https://youtube.com/playlist?list=PLrTJ8GEaDuZZWWng0XnTPdvWRpQHv6U2w",
#                      "https://youtube.com/playlist?list=PLMhqKsyei5dpED9kCu33f3SZmJKX7RBtk",
#                      "https://youtube.com/playlist?list=PL0p51VbAATAd04aLOKapIkgOyCYv9f14w",
#                      "https://youtube.com/playlist?list=PLpPrPUzzk7gaFxIGV3Xqcx21kC25M_MPt",
#                      "https://youtube.com/playlist?list=PLfQvHGiud6RrnCjiBsw5BVbVRPlBnWJWv",
#                      "https://youtube.com/playlist?list=PL4cJJVRBlBo3t8Fasf-6RMICtTl64PJuW",
#                      "https://youtube.com/playlist?list=PLnvkw2ct2N15zH3F3ZcvsZOajsnAyutem",
#                      "https://youtube.com/playlist?list=PLnXc-kZVDOPo7S5PtFcuvJ7CxqC4Ol-5W",
#                      "https://youtube.com/playlist?list=PLYTFtaYC02-z_lHBSxaoeNKm_64TVDAHf",
#                      "https://youtube.com/playlist?list=PLvtFwLg0kO-95uJ--lmezwksA3HID5Wir",
#                      "https://youtube.com/playlist?list=PLMC9KNkIncKtPzgY-5rmhvj7fax8fdxoj",
#                      "https://youtube.com/playlist?list=PLomnF-6GejKEfXSEvgnjJtFB4C7P0e9kj",
#                      "https://youtube.com/playlist?list=PLTVRe9aECZ6eFMc7LUtXta79M-kq8hCM8",
#                      "https://youtube.com/playlist?list=PL64G6j8ePNureM8YCKy5nRFyzYf8I2noy",
#                      "https://youtube.com/playlist?list=PLLCY4xuRnY_dNEf-2ilAVORZep_hJkzYl",
#                      "https://youtube.com/playlist?list=PL402o3EF36WFYAkkbooB3rlLrka9zQWjB",
#                      "https://youtube.com/playlist?list=PL_k9bFPONrNeOiaJRDK9qSSAbjXaEeoPS",
#                      "https://youtube.com/playlist?list=PLAG4o1kV1ZE-WhdTfjAllCpenPWjKx71O",
#                      "https://youtube.com/playlist?list=PL3mpgmWgY2iDwH2s8NnqudTMdUkMKGcQi",
#                      "https://youtube.com/playlist?list=PL5a6hmJETjjZWcknCDwH-AvqriMK7jzH8"]

wav_path = "/Users/phoebe/DJ-Box_model/dataset/music_dataset"

csv_path = '/Users/phoebe/DJ-Box_model/input/songs_feature_v3.csv'

# 下載並取得特徵
data = DownloadAndExtracFeature(youtube_lists_url, mp4_path, wav_path, csv_path)
# Out:
# 成功下載: 0.mp4:Gangnam Style
# 成功轉換: 0.wav
# 成功取得特徵: 0.wav
# 成功下載: 1.mp4:Uptown Funk (Official Video)
# 成功轉換: 1.wav
# 成功取得特徵: 1.wav
# 成功下載: 2.mp4:Work (Official Video)
# 成功轉換: 2.wav
# 成功取得特徵: 2.wav
# 成功下載: 3.mp4:Without Me
# 成功轉換: 3.wav
# 成功取得特徵: 3.wav
# 成功下載: 4.mp4:As It Was
# 成功轉換: 4.wav
# 成功取得特徵: 4.wav
# 成功下載: 5.mp4:Scary Slope
# 成功轉換: 5.wav
# 成功取得特徵: 5.wav
# 成功下載: 6.mp4:Dance The Night (From Barbie The Album)
# 成功轉換: 6.wav
# 成功取得特徵: 6.wav
# 成功下載: 7.mp4:Rush (Official Music Video)
# 成功轉換: 7.wav
# 成功取得特徵: 7.wav
# 成功下載: 8.mp4:Love On You (Dirty)
# 成功轉換: 8.wav
# 成功取得特徵: 8.wav
# 成功下載: 9.mp4:Starboy
# 成功轉換: 9.wav
# 成功取得特徵: 9.wav
# 成功下載: 10.mp4:Dusa
# 成功轉換: 10.wav
# 成功取得特徵: 10.wav
# 成功下載: 11.mp4:Lean On
# 成功轉換: 11.wav
# 成功取得特徵: 11.wav
# 成功下載: 12.mp4:Believer (Official Music Video)
# 成功轉換: 12.wav
# 成功取得特徵: 12.wav
# 成功下載: 13.mp4:Roar
# 成功轉換: 13.wav
# 成功取得特徵: 13.wav
# 成功下載: 14.mp4:Wan Billz - What’s The Difference Ft. Internet Money (Official Video)
# 成功轉換: 14.wav
# 成功取得特徵: 14.wav
# 成功下載: 15.mp4:Numb
# 成功轉換: 15.wav
# 成功取得特徵: 15.wav
# 成功下載: 16.mp4:Let Me Love You
# 成功轉換: 16.wav
# 成功取得特徵: 16.wav
# 成功下載: 17.mp4:Bloom
# 成功轉換: 17.wav
# 成功取得特徵: 17.wav
# 成功下載: 18.mp4:On The Floor (Radio Edit)
# 成功轉換: 18.wav
# 成功取得特徵: 18.wav
# 成功下載: 19.mp4:New Rules
# 成功轉換: 19.wav
# 成功取得特徵: 19.wav
# 成功下載: 20.mp4:Thunder
# 成功轉換: 20.wav
# 成功取得特徵: 20.wav
# 成功下載: 21.mp4:slurpy
# 成功轉換: 21.wav
# 成功取得特徵: 21.wav
# 成功下載: 22.mp4:Blinding Lights (Official Audio)
# 成功轉換: 22.wav
# 成功取得特徵: 22.wav
# 成功下載: 23.mp4:Bones (Official Lyric Video)
# 成功轉換: 23.wav
# 成功取得特徵: 23.wav
# 成功下載: 24.mp4:Hips Don't Lie (Official 4K Video)
# 成功轉換: 24.wav
# 成功取得特徵: 24.wav
# 成功下載: 25.mp4:John Alex Gatsby - Take You Out (Lyric Video)
# 成功轉換: 25.wav
# 成功取得特徵: 25.wav
# 成功下載: 26.mp4:Faded
# 成功轉換: 26.wav
# 成功取得特徵: 26.wav
# 成功下載: 27.mp4:Poker Face
# 成功轉換: 27.wav
# 成功取得特徵: 27.wav
# 成功下載: 28.mp4:Olla - Fly Away (Official Music Video)
# 成功轉換: 28.wav
# 成功取得特徵: 28.wav
# 成功下載: 29.mp4:BTS (방탄소년단) Sing 'Dynamite' with me
# 成功轉換: 29.wav
# 成功取得特徵: 29.wav
# 成功下載: 30.mp4:Cheap Thrills (Performance Edit)
# 成功轉換: 30.wav
# 成功取得特徵: 30.wav
# 成功下載: 31.mp4:TOXIC (Official Music Video)
# 成功轉換: 31.wav
# 成功取得特徵: 31.wav
# 成功下載: 32.mp4:Baby
# 成功轉換: 32.wav
# 成功取得特徵: 32.wav
# 成功下載: 33.mp4:It's My Life
# 成功轉換: 33.wav
# 成功取得特徵: 33.wav
# 成功下載: 34.mp4:Winona
# 成功轉換: 34.wav
# 成功取得特徵: 34.wav
# 成功下載: 35.mp4:Waiting For Love [blank]
# 成功轉換: 35.wav
# 成功取得特徵: 35.wav
# 成功下載: 36.mp4:Happy (Video)
# 成功轉換: 36.wav
# 成功取得特徵: 36.wav
# 成功下載: 37.mp4:Don't Let Me Down
# 成功轉換: 37.wav
# 成功取得特徵: 37.wav
# 成功下載: 38.mp4:Don’t Get Me Wrong
# 成功轉換: 38.wav
# 成功取得特徵: 38.wav
# 成功下載: 39.mp4:STAY
# 成功轉換: 39.wav
# 成功取得特徵: 39.wav
# 成功下載: 40.mp4:Empire State Of Mind
# 成功轉換: 40.wav
# 成功取得特徵: 40.wav
# 成功下載: 41.mp4:Big Hit (Intro) (Live)
# 成功轉換: 41.wav
# 成功取得特徵: 41.wav
# 成功下載: 42.mp4:Shake It Off
# 成功轉換: 42.wav
# 成功取得特徵: 42.wav
# 成功下載: 43.mp4:Rockabye
# 成功轉換: 43.wav
# 成功取得特徵: 43.wav
# 成功下載: 44.mp4:My Flow (Official Music Video)
# 成功轉換: 44.wav
# 成功取得特徵: 44.wav
# 成功下載: 45.mp4:No Lie
# 成功轉換: 45.wav
# 成功取得特徵: 45.wav
# 成功下載: 46.mp4:I'm Good (Blue)
# 成功轉換: 46.wav
# 成功取得特徵: 46.wav
# 成功下載: 47.mp4:Best Summer
# 成功轉換: 47.wav
# 成功取得特徵: 47.wav
# 成功下載: 48.mp4:DJ Snake ft. Selena Gomez, Ozuna & Cardi B - Taki Taki (Official Audio)
# 成功轉換: 48.wav
# 成功取得特徵: 48.wav
# 成功下載: 49.mp4:Something Just Like This (Lyric)
# 成功轉換: 49.wav
# 成功取得特徵: 49.wav
# 成功下載: 50.mp4:In The Vault
# 成功轉換: 50.wav
# 成功取得特徵: 50.wav
# 成功下載: 51.mp4:Bad Romance
# 成功轉換: 51.wav
# 成功取得特徵: 51.wav
# 成功下載: 52.mp4:GIRL LIKE ME (Official Music Video)
# 成功轉換: 52.wav
# 成功取得特徵: 52.wav
# 成功下載: 53.mp4:Nxuro x Lonedon - How Eh Style Guh (Official Music Video)
# 成功轉換: 53.wav
# 成功取得特徵: 53.wav
# 成功下載: 54.mp4:Unforgettable
# 成功轉換: 54.wav
# 成功取得特徵: 54.wav
# 成功下載: 55.mp4:Solo
# 成功轉換: 55.wav
# 成功取得特徵: 55.wav
# 成功下載: 56.mp4:Jealous Friend - Boogie (Official Lyric Video)
# 成功轉換: 56.wav
# 成功取得特徵: 56.wav
# 成功下載: 57.mp4:CAN'T STOP THE FEELING! (Original Song from DreamWorks Animation's "TROLLS")
# 成功轉換: 57.wav
# 成功取得特徵: 57.wav
# 成功下載: 58.mp4:Sorry
# 成功轉換: 58.wav
# 成功取得特徵: 58.wav
# 成功下載: 59.mp4:Buried By Dawg - The Hype ft. Nico Ghost
# 成功轉換: 59.wav
# 成功取得特徵: 59.wav
# 成功下載: 60.mp4:Party Rock Anthem
# 成功轉換: 60.wav
# 成功取得特徵: 60.wav
# 成功下載: 61.mp4:Worth It (Official Video)
# 成功轉換: 61.wav
# 成功取得特徵: 61.wav
# 成功下載: 62.mp4:Donae'o ft O.G Relli - Swaggy (Official Music Video)
# 成功轉換: 62.wav
# 成功取得特徵: 62.wav
# 成功下載: 63.mp4:The Way I Are Closed Captioned
# 成功轉換: 63.wav
# 成功取得特徵: 63.wav
# 成功下載: 64.mp4:Sugar
# 成功轉換: 64.wav
# 成功取得特徵: 64.wav
# 成功下載: 65.mp4:Tub of Love
# 成功轉換: 65.wav
# 成功取得特徵: 65.wav
# 成功下載: 66.mp4:Locked Out of Heaven
# 成功轉換: 66.wav
# 成功取得特徵: 66.wav
# 成功下載: 67.mp4:Don't You Worry Child (Radio Edit)
# 成功轉換: 67.wav
# 成功取得特徵: 67.wav
# 成功下載: 68.mp4:Lil Lud - Up Now (feat. Lethal Weapon) [Official Music Video]
# 成功轉換: 68.wav
# 成功取得特徵: 68.wav
# 成功下載: 69.mp4:Whenever, Wherever (Official HD Video)
# 成功轉換: 69.wav
# 成功取得特徵: 69.wav
# 成功下載: 70.mp4:Alone
# 成功轉換: 70.wav
# 成功取得特徵: 70.wav
# 成功下載: 71.mp4:Seventeen (Official Music Video)
# 成功轉換: 71.wav
# 成功取得特徵: 71.wav
# 成功下載: 72.mp4:Say My Name
# 成功轉換: 72.wav
# 成功取得特徵: 72.wav
# 成功下載: 73.mp4:Love Me Again - Radio Edit
# 成功轉換: 73.wav
# 成功取得特徵: 73.wav
# 成功下載: 74.mp4:Shy
# 成功轉換: 74.wav
# 成功取得特徵: 74.wav
# 成功下載: 75.mp4:Give Me Everything
# 成功轉換: 75.wav
# 成功取得特徵: 75.wav
# 成功下載: 76.mp4:I Gotta Feeling
# 成功轉換: 76.wav
# 成功取得特徵: 76.wav
# 成功下載: 77.mp4:Caught Feelings - Official Music Video
# 成功轉換: 77.wav
# 成功取得特徵: 77.wav
# 成功下載: 78.mp4:Don't Cha Closed Captioned, Busta Version
# 成功轉換: 78.wav
# 成功取得特徵: 78.wav
# 成功下載: 79.mp4:Butter
# 成功轉換: 79.wav
# 成功取得特徵: 79.wav
# 成功下載: 80.mp4:Hit They Block
# 成功轉換: 80.wav
# 成功取得特徵: 80.wav
# 成功下載: 81.mp4:Thrift Shop
# 成功轉換: 81.wav
# 成功取得特徵: 81.wav
# 成功下載: 82.mp4:There's Nothing Holdin' Me Back
# 成功轉換: 82.wav
# 成功取得特徵: 82.wav
# 成功下載: 83.mp4:XENA
# 成功轉換: 83.wav
# 成功取得特徵: 83.wav
# 成功下載: 84.mp4:Animals
# 成功轉換: 84.wav
# 成功取得特徵: 84.wav
# 成功下載: 85.mp4:Crazy In Love
# 成功轉換: 85.wav
# 成功取得特徵: 85.wav
# 成功下載: 86.mp4:Take It Off
# 成功轉換: 86.wav
# 成功取得特徵: 86.wav
# 成功下載: 87.mp4:Wake Me Up (Official Lyric Video)
# 成功轉換: 87.wav
# 成功取得特徵: 87.wav
# 成功下載: 88.mp4:What Makes You Beautiful (Official Video)
# 成功轉換: 88.wav
# 成功取得特徵: 88.wav
# 成功下載: 89.mp4:"Get Lost" (Lyric Video)
# 成功轉換: 89.wav
# 成功取得特徵: 89.wav
# 成功下載: 90.mp4:Don't Be Shy (Pt. II)
# 成功轉換: 90.wav
# 成功取得特徵: 90.wav
# 成功下載: 91.mp4:I Like It
# 成功轉換: 91.wav
# 成功取得特徵: 91.wav
# 成功下載: 92.mp4:Mine
# 成功轉換: 92.wav
# 成功取得特徵: 92.wav
# 成功下載: 93.mp4:Call Me Maybe
# 成功轉換: 93.wav
# 成功取得特徵: 93.wav
# 成功下載: 94.mp4:Bang Bang
# 成功轉換: 94.wav
# 成功取得特徵: 94.wav
# 成功下載: 95.mp4:MARJA'KIM - Latto "Put It On Da Floor" Challenge | WENEVADONE Entertainment
# 成功轉換: 95.wav
# 成功取得特徵: 95.wav
# 成功下載: 96.mp4:24K・マジック
# 成功轉換: 96.wav
# 成功取得特徵: 96.wav
# 成功下載: 97.mp4:red flag collector
# 成功轉換: 97.wav
# 成功取得特徵: 97.wav
# 成功下載: 98.mp4:TRUSTFALL
# 成功轉換: 98.wav
# 成功取得特徵: 98.wav
# 成功下載: 99.mp4:Whatever It Takes (360 Version/Lyric Vide​o)
# 成功轉換: 99.wav
# 成功取得特徵: 99.wav
# 成功下載: 100.mp4:i hate love (Live at The Belasco Theater)
# 成功轉換: 100.wav
# 成功取得特徵: 100.wav
# 成功下載: 101.mp4:I Took A Pill In Ibiza (Seeb Remix)
# 成功轉換: 101.wav
# 成功取得特徵: 101.wav
# 成功下載: 102.mp4:Memories
# 成功轉換: 102.wav
# 成功取得特徵: 102.wav
# 成功下載: 103.mp4:Clean Bandit - Symphony (Lyrics) feat. Zara Larsson
# 成功轉換: 103.wav
# 成功取得特徵: 103.wav
# 成功下載: 104.mp4:Where Have You Been
# 成功轉換: 104.wav
# 成功取得特徵: 104.wav
# 成功下載: 105.mp4:DON'T YOU WORRY
# 成功轉換: 105.wav
# 成功取得特徵: 105.wav
# 成功下載: 106.mp4:Ocean Drive
# 成功轉換: 106.wav
# 成功取得特徵: 106.wav
# 成功下載: 107.mp4:This Is What You Came For
# 成功轉換: 107.wav
# 成功取得特徵: 107.wav
# 成功下載: 108.mp4:Into You - Ariana Grande (Lyrics)
# 成功轉換: 108.wav
# 成功取得特徵: 108.wav
# 成功下載: 109.mp4:Alors On Danse Video
# 成功轉換: 109.wav
# 成功取得特徵: 109.wav
# 下載失败: IncompleteRead(72979 bytes read, 5410794 more expected)
# 成功下載: 110.mp4:Can't Remember to Forget You (Official Video)
# 成功轉換: 110.wav
# 成功取得特徵: 110.wav
# 成功下載: 111.mp4:In My Mind
# 成功轉換: 111.wav
# 成功取得特徵: 111.wav
# 成功下載: 112.mp4:Stitches
# 成功轉換: 112.wav
# 成功取得特徵: 112.wav
# 成功下載: 113.mp4:In the Name of Love
# 成功轉換: 113.wav
# 成功取得特徵: 113.wav
# 成功下載: 114.mp4:Love Again
# 成功轉換: 114.wav
# 成功取得特徵: 114.wav
# 成功下載: 115.mp4:Rain Over Me
# 成功轉換: 115.wav
# 成功取得特徵: 115.wav
# 成功下載: 116.mp4:Locked Away (Lyric Video)
# 成功轉換: 116.wav
# 成功取得特徵: 116.wav
# 成功下載: 117.mp4:Timber (Audio)
# 成功轉換: 117.wav
# 成功取得特徵: 117.wav
# 成功下載: 118.mp4:World's Smallest Violin
# 成功轉換: 118.wav
# 成功取得特徵: 118.wav
# 成功下載: 119.mp4:Shameless (Official Video)
# 成功轉換: 119.wav
# 成功取得特徵: 119.wav
# 成功下載: 120.mp4:Calvin Harris & Ellie Goulding - Miracle (Extended Mix)
# 成功轉換: 120.wav
# 成功取得特徵: 120.wav
# 成功下載: 121.mp4:Eenie Meenie (Official Video)
# 成功轉換: 121.wav
# 成功取得特徵: 121.wav
# 成功下載: 122.mp4:Alone
# 成功轉換: 122.wav
# 成功取得特徵: 122.wav
# 成功下載: 123.mp4:She Doesn't Mind
# 成功轉換: 123.wav
# 成功取得特徵: 123.wav
# 成功下載: 124.mp4:Levels
# 成功轉換: 124.wav
# 成功取得特徵: 124.wav
# 成功下載: 125.mp4:Don't Stop the Music
# 成功轉換: 125.wav
# 成功取得特徵: 125.wav
# 成功下載: 126.mp4:Black Magic
# 成功轉換: 126.wav
# 成功取得特徵: 126.wav
# 成功下載: 127.mp4:I'm an Albatraoz (Audio)
# 成功轉換: 127.wav
# 成功取得特徵: 127.wav
# 成功下載: 128.mp4:High Hopes
# 成功轉換: 128.wav
# 成功取得特徵: 128.wav
# 成功下載: 129.mp4:Perfect Strangers
# 成功轉換: 129.wav
# 成功取得特徵: 129.wav
# 成功下載: 130.mp4:Don't Start Now
# 成功轉換: 130.wav
# 成功取得特徵: 130.wav
# 成功下載: 131.mp4:Solo
# 成功轉換: 131.wav
# 成功取得特徵: 131.wav
# 成功下載: 132.mp4:Toxic (Instrumental)
# 成功轉換: 132.wav
# 成功取得特徵: 132.wav
# 成功下載: 133.mp4:Mr. Saxobeat
# 成功轉換: 133.wav
# 成功取得特徵: 133.wav
# 成功下載: 134.mp4:Burn
# 成功轉換: 134.wav
# 成功取得特徵: 134.wav
# 成功下載: 135.mp4:Roses (Imanbek Remix)
# 成功轉換: 135.wav
# 成功取得特徵: 135.wav
# 成功下載: 136.mp4:One Kiss (Official Video)
# 成功轉換: 136.wav
# 成功取得特徵: 136.wav
# 成功下載: 137.mp4:Hung Up
# 成功轉換: 137.wav
# 成功取得特徵: 137.wav
# 成功下載: 138.mp4:Hey Mama
# 成功轉換: 138.wav
# 成功取得特徵: 138.wav
# 成功下載: 139.mp4:How Deep Is Your Love (Audio)
# 成功轉換: 139.wav
# 成功取得特徵: 139.wav
# 成功下載: 140.mp4:Single Ladies (Put a Ring on It) (Video Version)
# 成功轉換: 140.wav
# 成功取得特徵: 140.wav
# 成功下載: 141.mp4:International Love
# 成功轉換: 141.wav
# 成功取得特徵: 141.wav
# 成功下載: 142.mp4:Summer
# 成功轉換: 142.wav
# 成功取得特徵: 142.wav
# 成功下載: 143.mp4:Hey Ya!
# 成功轉換: 143.wav
# 成功取得特徵: 143.wav
# 成功下載: 144.mp4:Maps
# 成功轉換: 144.wav
# 成功取得特徵: 144.wav
# 成功下載: 145.mp4:Turn Down for What
# 成功轉換: 145.wav
# 成功取得特徵: 145.wav
# 成功下載: 146.mp4:Good Feeling
# 成功轉換: 146.wav
# 成功取得特徵: 146.wav
# 成功下載: 147.mp4:ATC - All Around The World (la la la la la la la la)
# 成功轉換: 147.wav
# 成功取得特徵: 147.wav
# 成功下載: 148.mp4:Cold Water
# 成功轉換: 148.wav
# 成功取得特徵: 148.wav
# 成功下載: 149.mp4:The Nights
# 成功轉換: 149.wav
# 成功取得特徵: 149.wav
# 成功下載: 150.mp4:The Monster
# 成功轉換: 150.wav
# 成功取得特徵: 150.wav
# 成功下載: 151.mp4:1, 2, 3
# 成功轉換: 151.wav
# 成功取得特徵: 151.wav
# 成功下載: 152.mp4:Swalla
# 成功轉換: 152.wav
# 成功取得特徵: 152.wav
# 成功下載: 153.mp4:Makeba
# 成功轉換: 153.wav
# 成功取得特徵: 153.wav
# 成功下載: 154.mp4:Physical
# 成功轉換: 154.wav
# 成功取得特徵: 154.wav
# 成功下載: 155.mp4:Mood
# 成功轉換: 155.wav
# 成功取得特徵: 155.wav
# 成功下載: 156.mp4:Heart Attack Official Video
# 成功轉換: 156.wav
# 成功取得特徵: 156.wav
# 成功下載: 157.mp4:Me and My Broken Heart
# 成功轉換: 157.wav
# 成功取得特徵: 157.wav
# 成功下載: 158.mp4:Bastille - Pompeii (Lyrics)
# 成功轉換: 158.wav
# 成功取得特徵: 158.wav
# 成功下載: 159.mp4:Rihanna - Only Girl (In The World) (Audio)
# 成功轉換: 159.wav
# 成功取得特徵: 159.wav
# 成功下載: 160.mp4:Fresh
# 成功轉換: 160.wav
# 成功取得特徵: 160.wav
# 成功下載: 161.mp4:Hot N Cold
# 成功轉換: 161.wav
# 成功取得特徵: 161.wav
# 成功下載: 162.mp4:Way Back Home [Sam Feldt Edit] (Lyric Video)
# 成功轉換: 162.wav
# 成功取得特徵: 162.wav
# 成功下載: 163.mp4:Cake By the Ocean
# 成功轉換: 163.wav
# 成功取得特徵: 163.wav
# 成功下載: 164.mp4:Animals Lyric Video
# 成功轉換: 164.wav
# 成功取得特徵: 164.wav
# 成功下載: 165.mp4:Lady (Hear Me Tonight)
# 成功轉換: 165.wav
# 成功取得特徵: 165.wav
# 成功下載: 166.mp4:Ain't Your Mama (Official Video)
# 成功轉換: 166.wav
# 成功取得特徵: 166.wav
# 成功下載: 167.mp4:Bad
# 成功轉換: 167.wav
# 成功取得特徵: 167.wav
# 成功下載: 168.mp4:World,Hold On (Children of the Sky) - Radio Edit 2
# 成功轉換: 168.wav
# 成功取得特徵: 168.wav
# 成功下載: 169.mp4:Sun Goes Down
# 成功轉換: 169.wav
# 成功取得特徵: 169.wav
# 成功下載: 170.mp4:Play Hard
# 成功轉換: 170.wav
# 成功取得特徵: 170.wav
# 成功下載: 171.mp4:Stronger (What Doesn't Kill You)
# 成功轉換: 171.wav
# 成功取得特徵: 171.wav
# 成功下載: 172.mp4:Firework (Official Music Video)
# 成功轉換: 172.wav
# 成功取得特徵: 172.wav
# 成功下載: 173.mp4:TiK ToK (Official HD Video)
# 成功轉換: 173.wav
# 成功取得特徵: 173.wav
# 成功下載: 174.mp4:Let You Love Me
# 成功轉換: 174.wav
# 成功取得特徵: 174.wav
# 成功下載: 175.mp4:Temperature (VIDEO video version with Breakout Outro)
# 成功轉換: 175.wav
# 成功取得特徵: 175.wav
# 成功下載: 176.mp4:California Gurls (Official Music Video)
# 成功轉換: 176.wav
# 成功取得特徵: 176.wav
# 成功下載: 177.mp4:Rudimental - These Days (Lyrics) Ft. Jess Glynne, Macklemore & Dan Caplen
# 成功轉換: 177.wav
# 成功取得特徵: 177.wav
# 成功下載: 178.mp4:Breaking Me
# 成功轉換: 178.wav
# 成功取得特徵: 178.wav
# 成功下載: 179.mp4:Super Bass
# 成功轉換: 179.wav
# 成功取得特徵: 179.wav
# 成功下載: 180.mp4:Sexy Bitch
# 成功轉換: 180.wav
# 成功取得特徵: 180.wav
# 成功下載: 181.mp4:Be the One
# 成功轉換: 181.wav
# 成功取得特徵: 181.wav
# 成功下載: 182.mp4:Tiësto - 10:35 (Official Lyric Video) ft. Tate McRae
# 成功轉換: 182.wav
# 成功取得特徵: 182.wav
# 成功下載: 183.mp4:Natural
# 成功轉換: 183.wav
# 成功取得特徵: 183.wav
# 成功下載: 184.mp4:Wild Ones
# 成功轉換: 184.wav
# 成功取得特徵: 184.wav
# 成功下載: 185.mp4:Me Too
# 成功轉換: 185.wav
# 成功取得特徵: 185.wav
# 成功下載: 186.mp4:Hey Brother
# 成功轉換: 186.wav
# 成功取得特徵: 186.wav
# 成功下載: 187.mp4:How We Do
# 成功轉換: 187.wav
# 成功取得特徵: 187.wav
# 成功下載: 188.mp4:Treasure
# 成功轉換: 188.wav
# 成功取得特徵: 188.wav
# 成功下載: 189.mp4:All About That Bass (Official Video)
# 成功轉換: 189.wav
# 成功取得特徵: 189.wav
# 成功下載: 190.mp4:The Pretender
# 成功轉換: 190.wav
# 成功取得特徵: 190.wav
# 成功下載: 191.mp4:Amazing
# 成功轉換: 191.wav
# 成功取得特徵: 191.wav
# 成功下載: 192.mp4:Cool for the Summer (Official Lyric Video)
# 成功轉換: 192.wav
# 成功取得特徵: 192.wav
# 成功下載: 193.mp4:Take You Dancing
# 成功轉換: 193.wav
# 成功取得特徵: 193.wav
# 成功下載: 194.mp4:Whistle (Acapella)
# 成功轉換: 194.wav
# 成功取得特徵: 194.wav
# 成功下載: 195.mp4:Celebrate
# 成功轉換: 195.wav
# 成功取得特徵: 195.wav
# 成功下載: 196.mp4:Daniel Valentino - Gold Dust
# 成功轉換: 196.wav
# 成功取得特徵: 196.wav
# 成功下載: 197.mp4:Top Floor (Official Video)
# 成功轉換: 197.wav
# 成功取得特徵: 197.wav
# 成功下載: 198.mp4:Body Like Sza
# 成功轉換: 198.wav
# 成功取得特徵: 198.wav
# 成功下載: 199.mp4:Lucky
# 成功轉換: 199.wav
# 成功取得特徵: 199.wav
# 成功下載: 200.mp4:ELYAZ - Wildlands (Official Video)
# 成功轉換: 200.wav
# 成功取得特徵: 200.wav
# 成功下載: 201.mp4:Rap God
# 成功轉換: 201.wav
# 成功取得特徵: 201.wav
# 成功下載: 202.mp4:Bad Memories
# 成功轉換: 202.wav
# 成功取得特徵: 202.wav
# 成功下載: 203.mp4:Judas
# 成功轉換: 203.wav
# 成功取得特徵: 203.wav
# 成功下載: 204.mp4:Just Dance Closed Captioned
# 成功轉換: 204.wav
# 成功取得特徵: 204.wav
# 成功下載: 205.mp4:UR SO FULL OF IT
# 成功轉換: 205.wav
# 成功取得特徵: 205.wav
# 成功下載: 206.mp4:Be My Lover (2023 Mix)
# 成功轉換: 206.wav
# 成功取得特徵: 206.wav
# 成功下載: 207.mp4:We Found Love Teaser Video
# 成功轉換: 207.wav
# 成功取得特徵: 207.wav
# 成功下載: 208.mp4:Dangerous
# 成功轉換: 208.wav
# 成功取得特徵: 208.wav
# 成功下載: 209.mp4:Drag Me Down (Official Video)
# 成功轉換: 209.wav
# 成功取得特徵: 209.wav
# 成功下載: 210.mp4:My Way
# 成功轉換: 210.wav
# 成功取得特徵: 210.wav
# 成功下載: 211.mp4:You're Gonna Go Far, Kid
# 成功轉換: 211.wav
# 成功取得特徵: 211.wav
# 成功下載: 212.mp4:Blame (Audio)
# 成功轉換: 212.wav
# 成功取得特徵: 212.wav
# 成功下載: 213.mp4:The Motto
# 成功轉換: 213.wav
# 成功取得特徵: 213.wav
# 成功下載: 214.mp4:I Know You Want Me (Calle Ocho)
# 成功轉換: 214.wav
# 成功取得特徵: 214.wav
# 成功下載: 215.mp4:22
# 成功轉換: 215.wav
# 成功取得特徵: 215.wav
# 成功下載: 216.mp4:Stay (Official Music Video)
# 成功轉換: 216.wav
# 成功取得特徵: 216.wav
# 成功下載: 217.mp4:Feedback
# 成功轉換: 217.wav
# 成功取得特徵: 217.wav
# 成功下載: 218.mp4:Down On Me
# 成功轉換: 218.wav
# 成功取得特徵: 218.wav
# 成功下載: 219.mp4:Do It Again
# 成功轉換: 219.wav
# 成功取得特徵: 219.wav
# 成功下載: 220.mp4:My Head & My Heart
# 成功轉換: 220.wav
# 成功取得特徵: 220.wav
# 成功下載: 221.mp4:Forever (Official HD Video)
# 成功轉換: 221.wav
# 成功取得特徵: 221.wav
# 成功下載: 222.mp4:Bam Bam (Official Audio)
# 成功轉換: 222.wav
# 成功取得特徵: 222.wav
# 成功下載: 223.mp4:Maan Meri Jaan (Afterlife)
# 成功轉換: 223.wav
# 成功取得特徵: 223.wav
# 成功下載: 224.mp4:Smiley - Eternals (Official Video)
# 成功轉換: 224.wav
# 成功取得特徵: 224.wav
# 成功下載: 225.mp4:Over Again
# 成功轉換: 225.wav
# 成功取得特徵: 225.wav
# 成功下載: 226.mp4:Beggin
# 成功轉換: 226.wav
# 成功取得特徵: 226.wav
# 成功下載: 227.mp4:Baby Don't Hurt Me
# 成功轉換: 227.wav
# 成功取得特徵: 227.wav
# 成功下載: 228.mp4:All Nighter
# 成功轉換: 228.wav
# 成功取得特徵: 228.wav
# 成功下載: 229.mp4:Olla - Weightless (Official Music Video)
# 成功轉換: 229.wav
# 成功取得特徵: 229.wav
# 成功下載: 230.mp4:Coi Leray - Players (DJ Smallz 732 Jersey Club TikTok Remix) Lyrics | i just wanna have a good night
# 成功轉換: 230.wav
# 成功取得特徵: 230.wav
# 成功下載: 231.mp4:INDUSTRY BABY
# 成功轉換: 231.wav
# 成功取得特徵: 231.wav
# 成功下載: 232.mp4:The Drum
# 成功轉換: 232.wav
# 成功取得特徵: 232.wav
# 成功下載: 233.mp4:Life is a Highway
# 成功轉換: 233.wav
# 成功取得特徵: 233.wav
# 成功下載: 234.mp4:Telephone
# 成功轉換: 234.wav
# 成功取得特徵: 234.wav
# 成功下載: 235.mp4:This Girl (Kungs Vs. Cookin' On 3 Burners)
# 成功轉換: 235.wav
# 成功取得特徵: 235.wav
# 成功下載: 236.mp4:TROLLZ
# 成功轉換: 236.wav
# 成功取得特徵: 236.wav
# 成功下載: 237.mp4:E.T. - Katy Perry Featuring Kanye West (Lyrics on Screen)
# 成功轉換: 237.wav
# 成功取得特徵: 237.wav
# 成功下載: 238.mp4:SG
# 成功轉換: 238.wav
# 成功取得特徵: 238.wav
# 成功下載: 239.mp4:River
# 成功轉換: 239.wav
# 成功取得特徵: 239.wav
# 成功下載: 240.mp4:Clarity
# 成功轉換: 240.wav
# 成功取得特徵: 240.wav
# 成功下載: 241.mp4:Light Switch
# 成功轉換: 241.wav
# 成功取得特徵: 241.wav
# 成功下載: 242.mp4:Dolls
# 成功轉換: 242.wav
# 成功取得特徵: 242.wav
# 成功下載: 243.mp4:New Thang
# 成功轉換: 243.wav
# 成功取得特徵: 243.wav

# %%
# 儲存成 CSV
df = pd.DataFrame(data)
df.to_csv(csv_path)

# %%
# 刪除 MP4
dir = mp4_path
for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))
dir = wav_path
for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))
