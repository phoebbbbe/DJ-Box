# %%
from pytube import YouTube
from pytube import Playlist
from pydub import AudioSegment
from bs4 import BeautifulSoup
import requests
import os
from glob import glob
import openpyxl

# %% [markdown]
# ### 列出 ID Title Duration URL

# %%
def DownloadInfoAndWav(label, youtube_lists_url, mp4_path, wav_path, workbook_path, worksheet_name, start=0, min_length=60):
    
    # 遍歷播放清單
    video_urls = []

    for yt_list_url in youtube_lists_url:

        # 播放列表URL
        playlist_url = yt_list_url

        # 創建Playlist對象
        playlist = Playlist(yt_list_url)

        # 解析播放列表
        playlist._video_regex = r"\"url\":\"(/watch\?v=[\w-]*)"

        # 播放列表URL
        video_urls += playlist.video_urls

    # 提取每首歌曲的編號、歌名、長度、URL
    song_titles = []
    song_ids = []
    song_durations = []
    song_urls = []
    song_i = start

    # 遍歷播放列表URL
    for i, url in enumerate(video_urls):

        # 儲存歌曲清單
        # 創建YouTube對象
        yt = YouTube(url)

        if (yt.length > min_length):
            song_i += 1
            song_titles.append(yt.title)
            song_ids.append(f"{label}_{song_i}")
            song_durations.append(yt.length)
            song_urls.append(url)

    # 印出每首歌曲的ID清單，並存進 xlsx
    workbook = openpyxl.load_workbook(workbook_path)
    sheet = workbook[worksheet_name]

    print("----List Of Song ID----")
    row = start+1
    for songId in song_ids:
        row += 1
        sheet[f'A{row}'] = songId
        print(songId)

    # 印出每首歌曲的標題清單
    print("----List Of Song Title----")
    row = start+1
    for title in song_titles:
        row += 1
        sheet[f'B{row}'] = title
        print(title)

    # 印出每首歌曲的長度清單
    print("----List Of Song Duration----")
    row = start+1
    for duration in song_durations:
        row += 1
        sheet[f'C{row}'] = duration
        print(duration)

    # 印出每首歌曲的URL清單
    print("----List Of Song URL----")
    row = start+1
    for url in song_urls:
        row += 1
        sheet[f'D{row}'] = url
        print(url)

    workbook.save(workbook_path)
    
    DownloadMp4ToWav(song_urls, song_ids, mp4_path, wav_path)
    
    return

# %% [markdown]
# ### 下載 Youtube List 中每個影片

# %%
def DownloadMp4ToWav(song_urls, song_ids, mp4_path, wav_path):
    
    video_paths = []

    for i, url in enumerate(song_urls):
        try:
            # 創建YouTube對象
            youtube = YouTube(url)

            # 選擇最高質量的影片流
            video_stream = youtube.streams.get_highest_resolution()

            # 設定檔名
            file_name = f"{song_ids[i]}.mp4"

            # 下載影片
            video_file = video_stream.download(filename = file_name, 
                                               output_path = mp4_path)

            # 儲存影片路徑
            video_paths.append(f"{mp4_path}/{file_name}")

            print(f"成功下載: {youtube.title}")
        except Exception as e:
            print(f"下載失败: {str(e)}")

    # 印出每ㄧ MP4 的下載路徑清單
    print("List Of MP4 Path")
    for path in video_paths:
        print(path)
        
    for i, path in enumerate(video_paths):
    
        # 將 MP4 轉為 WAV 存起來
        mp4_audio = AudioSegment.from_file(path, "mp4")
        mp4_audio.export(f"{wav_path}/{song_ids[i]}.wav", format="wav")
        
        print(f"成功轉換: {song_ids[i]}.wav")
    
    # 刪除 MP4
    dir = mp4_path
    for f in os.listdir(dir):
        os.remove(os.path.join(dir, f))
    
    return

# %%
# 設定參數和路徑
mp4_path = "/Users/phoebe/DJ-Box_model/dataset/mp4_files"


youtube_lists_url = ["https://youtube.com/playlist?list=PLNhzyV4NWnWNkxh5FK-AITO2R_3JGCbcr",
                    "https://youtube.com/playlist?list=PLNhzyV4NWnWMzmQlRL9iIQok-J0rR5fGS"]

classes = "occasion"
label = "awards"
wav_path = f"/Users/phoebe/DJ-Box_model/dataset/music_dataset/{classes}_set/{label}"

workbook_path = "/Users/phoebe/DJ-Box_model/dataset/music_dataset.xlsx"
worksheet_name = f"{classes}_{label}"

# %%
# 取得歌曲資訊
start = 0    # 開始編號
min_length = 60  # 最短長度

DownloadInfoAndWav(label, youtube_lists_url, mp4_path, wav_path, workbook_path, worksheet_name, start, min_length)
# Out:
# ----List Of Song ID----
# wedding_1
# wedding_2
# wedding_3
# wedding_4
# wedding_5
# wedding_6
# wedding_7
# wedding_8
# wedding_9
# wedding_10
# wedding_11
# wedding_12
# wedding_13
# wedding_14
# wedding_15
# wedding_16
# wedding_17
# wedding_18
# wedding_19
# wedding_20
# wedding_21
# wedding_22
# wedding_23
# wedding_24
# wedding_25
# wedding_26
# wedding_27
# wedding_28
# wedding_29
# wedding_30
# wedding_31
# wedding_32
# wedding_33
# wedding_34
# wedding_35
# wedding_36
# wedding_37
# wedding_38
# wedding_39
# wedding_40
# wedding_41
# wedding_42
# wedding_43
# wedding_44
# wedding_45
# wedding_46
# wedding_47
# wedding_48
# wedding_49
# wedding_50
# wedding_51
# wedding_52
# wedding_53
# wedding_54
# wedding_55
# wedding_56
# ----List Of Song Title----
# Perfect
# Marry Me
# Thinking Out Loud
# Crispy脆樂團 [ 黑暗的盡頭 ] Official Music Video
# I Love You So
# Lucky
# How Long Will I Love You (Official Video)
# Kiss Me
# 不是因為天氣晴朗才愛你 (Instrumental)
# Way Back Into Love
# 李千娜 Nana Lee – 心花開 (Official Music Video)
# 愛你
# 有你的快樂
# A Rocket to the Moon
# 落日飛車-I Know You Know I Love You
# 旺福 Won Fu《我當你空氣 You Are My Air》 Official Music Video
# 王若琳 - 親密愛人 (The Things We Do For Love 2011年)
# 小さな恋のうた
# Ho Hey
# Tender
# 全世界我最喜歡你(可是你都不知道)
# ::首播:::旺福Won Fu [愛你一兆年 Love One Trillion Years] MV官方完整版
# I Love You 3000
# Otomen
# Dreaming With You
# 溫蒂漫步 Wendy Wander - 我想和你一起 (Official music video)
# Lover (Official Music Video)
# Marry Me (HBO Asia Original Series "Adventure of the Ring" Theme Song)
# Hubby
# 想和你一起
# 洪安妮 ANNI HUNG【我喜歡你 I Like you】Official Music Video
# 房東的貓《你是我最愚蠢的一次浪漫 》Lyric Video
# I Do
# 最重要的決定
# Sugar
# Say it! What are you doing?
# HENRY 헨리 'It's You' (Live Ver.)
# Until I Found You
# Love Me Like You Do [blank]
# Forever After All (Official Video)
# Can't Help Falling In Love (Official Audio)
# Love Story
# Crispy脆樂團 [ 愛是我們必經的辛苦 I Will Be There ] Official Music Video
# Express Love Letter (Live)
# 愛妳一萬年
# 伍佰 Wu Bai&China Blue【與妳到永久 Till the end of time】Official Music Video
# How Deep Is Your Love
# 這樣的我
# Me & You ◑ (Instrumental)
# 不再讓你孤單
# Gemini
# EVERYTHING
# You've Got My Heart
# Her - Karen O and Spike Jonze "The Moon Song" [HD]
# Wedding Songs | Best Wedding Songs 2023 ~ Collection Non Stop Playlist ~ Walking Down The Aisle
# 👰🏻💐🤵🏻 축가 하면 이 노래가 빠질 수 없지 사랑스러운 결혼식 축가 노래 모음 💽ㅣ파우제 플레이리스트
# ----List Of Song Duration----
# 280
# 241
# 297
# 332
# 160
# 201
# 158
# 197
# 241
# 278
# 201
# 220
# 197
# 281
# 122
# 236
# 280
# 223
# 162
# 300
# 318
# 265
# 210
# 245
# 228
# 422
# 238
# 201
# 271
# 235
# 255
# 212
# 169
# 239
# 301
# 217
# 139
# 176
# 249
# 240
# 181
# 237
# 271
# 223
# 495
# 258
# 239
# 672
# 244
# 332
# 303
# 304
# 164
# 141
# 4867
# 4829
# ----List Of Song URL----
# https://www.youtube.com/watch?v=2Vv-BfVoq4g
# https://www.youtube.com/watch?v=PzWvQNq_890
# https://www.youtube.com/watch?v=lp-EO5I60KA
# https://www.youtube.com/watch?v=k20rL10W6Nk
# https://www.youtube.com/watch?v=NwFVSclD_uc
# https://www.youtube.com/watch?v=acvIVA9-FMQ
# https://www.youtube.com/watch?v=an4ySOlsUMY
# https://www.youtube.com/watch?v=v45F0YesdZM
# https://www.youtube.com/watch?v=9_068Ekk_fs
# https://www.youtube.com/watch?v=0bwWy67MsOU
# https://www.youtube.com/watch?v=Qd33i-OoOk4
# https://www.youtube.com/watch?v=NAODcPQcy9U
# https://www.youtube.com/watch?v=qZiNigAO-zQ
# https://www.youtube.com/watch?v=3aCctY3DGac
# https://www.youtube.com/watch?v=xzYvMSWDytg
# https://www.youtube.com/watch?v=1hKkAM-ADDU
# https://www.youtube.com/watch?v=h5Oupn87dyU
# https://www.youtube.com/watch?v=JoJ6lnF07U4
# https://www.youtube.com/watch?v=zvCBSSwgtg4
# https://www.youtube.com/watch?v=1rluTF9Vzh4
# https://www.youtube.com/watch?v=3uIbahu_S6s
# https://www.youtube.com/watch?v=R59JreriTGQ
# https://www.youtube.com/watch?v=cPkE0IbDVs4
# https://www.youtube.com/watch?v=Vs9A65M3v-k
# https://www.youtube.com/watch?v=oSndJfjFuBU
# https://www.youtube.com/watch?v=ltFNlTWDgU8
# https://www.youtube.com/watch?v=-BjZmE2gtdo
# https://www.youtube.com/watch?v=9JxLFB4UuyY
# https://www.youtube.com/watch?v=UYWUAQhhR_g
# https://www.youtube.com/watch?v=0VdJ49flrlI
# https://www.youtube.com/watch?v=aDSf3QoK3uQ
# https://www.youtube.com/watch?v=DHMx_B9-zdY
# https://www.youtube.com/watch?v=cytXqxHqvLY
# https://www.youtube.com/watch?v=RmrVpCVoVJU
# https://www.youtube.com/watch?v=09R8_2nJtjg
# https://www.youtube.com/watch?v=SdHQkkRc-hc
# https://www.youtube.com/watch?v=lV-6aaW4tO8
# https://www.youtube.com/watch?v=GxldQ9eX2wo
# https://www.youtube.com/watch?v=AJtDXIazrMo
# https://www.youtube.com/watch?v=TDpOcp98b5k
# https://www.youtube.com/watch?v=vGJTaP6anOU
# https://www.youtube.com/watch?v=8xg3vE8Ie_E
# https://www.youtube.com/watch?v=adaiZilQdVw
# https://www.youtube.com/watch?v=JJhlRIN90YY
# https://www.youtube.com/watch?v=CgAJAmP14kQ
# https://www.youtube.com/watch?v=ZjCPy66w0Ng
# https://www.youtube.com/watch?v=XpqqjU7u5Yc
# https://www.youtube.com/watch?v=5hwnIgfO39Y
# https://www.youtube.com/watch?v=SB4Jra4zR80
# https://www.youtube.com/watch?v=jL_ua9Yc-oM
# https://www.youtube.com/watch?v=ba3vBuvKHk8
# https://www.youtube.com/watch?v=Aq_gsctWHtQ
# https://www.youtube.com/watch?v=3QKCxrhzg-M
# https://www.youtube.com/watch?v=CxahbnUCZxY
# https://www.youtube.com/watch?v=ITbVxvysTjA
# https://www.youtube.com/watch?v=Lryqqs6BcdA
# 成功下載: Perfect
# 成功下載: Marry Me
# 成功下載: Thinking Out Loud
# 成功下載: Crispy脆樂團 [ 黑暗的盡頭 ] Official Music Video
# 成功下載: I Love You So
# 成功下載: Lucky
# 成功下載: How Long Will I Love You (Official Video)
# 成功下載: Kiss Me
# 成功下載: 不是因為天氣晴朗才愛你 (Instrumental)
# 成功下載: Way Back Into Love
# 成功下載: 李千娜 Nana Lee – 心花開 (Official Music Video)
# 成功下載: 愛你
# 成功下載: 有你的快樂
# 成功下載: A Rocket to the Moon
# 成功下載: 落日飛車-I Know You Know I Love You
# 成功下載: 旺福 Won Fu《我當你空氣 You Are My Air》 Official Music Video
# 成功下載: 王若琳 - 親密愛人 (The Things We Do For Love 2011年)
# 成功下載: 小さな恋のうた
# 成功下載: Ho Hey
# 成功下載: Tender
# 成功下載: 全世界我最喜歡你(可是你都不知道)
# 成功下載: ::首播:::旺福Won Fu [愛你一兆年 Love One Trillion Years] MV官方完整版
# 成功下載: I Love You 3000
# 成功下載: Otomen
# 成功下載: Dreaming With You
# 成功下載: 溫蒂漫步 Wendy Wander - 我想和你一起 (Official music video)
# 成功下載: Lover (Official Music Video)
# 成功下載: Marry Me (HBO Asia Original Series "Adventure of the Ring" Theme Song)
# 成功下載: Hubby
# 成功下載: 想和你一起
# 成功下載: 洪安妮 ANNI HUNG【我喜歡你 I Like you】Official Music Video
# 成功下載: 房東的貓《你是我最愚蠢的一次浪漫 》Lyric Video
# 成功下載: I Do
# 成功下載: 最重要的決定
# 成功下載: Sugar
# 成功下載: Say it! What are you doing?
# 成功下載: HENRY 헨리 'It's You' (Live Ver.)
# 成功下載: Until I Found You
# 成功下載: Love Me Like You Do [blank]
# 成功下載: Forever After All (Official Video)
# 成功下載: Can't Help Falling In Love (Official Audio)
# 成功下載: Love Story
# 成功下載: Crispy脆樂團 [ 愛是我們必經的辛苦 I Will Be There ] Official Music Video
# 成功下載: Express Love Letter (Live)
# 成功下載: 愛妳一萬年
# 成功下載: 伍佰 Wu Bai&China Blue【與妳到永久 Till the end of time】Official Music Video
# 成功下載: How Deep Is Your Love
# 成功下載: 這樣的我
# 成功下載: Me & You ◑ (Instrumental)
# 成功下載: 不再讓你孤單
# 成功下載: Gemini
# 成功下載: EVERYTHING
# 成功下載: You've Got My Heart
# 成功下載: Her - Karen O and Spike Jonze "The Moon Song" [HD]
# 成功下載: Wedding Songs | Best Wedding Songs 2023 ~ Collection Non Stop Playlist ~ Walking Down The Aisle
# 成功下載: 👰🏻💐🤵🏻 축가 하면 이 노래가 빠질 수 없지 사랑스러운 결혼식 축가 노래 모음 💽ㅣ파우제 플레이리스트
# List Of MP4 Path
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_1.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_2.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_3.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_4.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_5.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_6.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_7.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_8.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_9.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_10.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_11.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_12.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_13.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_14.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_15.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_16.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_17.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_18.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_19.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_20.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_21.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_22.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_23.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_24.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_25.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_26.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_27.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_28.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_29.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_30.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_31.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_32.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_33.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_34.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_35.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_36.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_37.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_38.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_39.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_40.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_41.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_42.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_43.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_44.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_45.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_46.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_47.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_48.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_49.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_50.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_51.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_52.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_53.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_54.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_55.mp4
# /Users/phoebe/DJ-Box_model/dataset/mp4_files/wedding_56.mp4
# 成功轉換: wedding_1.wav
# 成功轉換: wedding_2.wav
# 成功轉換: wedding_3.wav
# 成功轉換: wedding_4.wav
# 成功轉換: wedding_5.wav
# 成功轉換: wedding_6.wav
# 成功轉換: wedding_7.wav
# 成功轉換: wedding_8.wav
# 成功轉換: wedding_9.wav
# 成功轉換: wedding_10.wav
# 成功轉換: wedding_11.wav
# 成功轉換: wedding_12.wav
# 成功轉換: wedding_13.wav
# 成功轉換: wedding_14.wav
# 成功轉換: wedding_15.wav
# 成功轉換: wedding_16.wav
# 成功轉換: wedding_17.wav
# 成功轉換: wedding_18.wav
# 成功轉換: wedding_19.wav
# 成功轉換: wedding_20.wav
# 成功轉換: wedding_21.wav
# 成功轉換: wedding_22.wav
# 成功轉換: wedding_23.wav
# 成功轉換: wedding_24.wav
# 成功轉換: wedding_25.wav
# 成功轉換: wedding_26.wav
# 成功轉換: wedding_27.wav
# 成功轉換: wedding_28.wav
# 成功轉換: wedding_29.wav
# 成功轉換: wedding_30.wav
# 成功轉換: wedding_31.wav
# 成功轉換: wedding_32.wav
# 成功轉換: wedding_33.wav
# 成功轉換: wedding_34.wav
# 成功轉換: wedding_35.wav
# 成功轉換: wedding_36.wav
# 成功轉換: wedding_37.wav
# 成功轉換: wedding_38.wav
# 成功轉換: wedding_39.wav
# 成功轉換: wedding_40.wav
# 成功轉換: wedding_41.wav
# 成功轉換: wedding_42.wav
# 成功轉換: wedding_43.wav
# 成功轉換: wedding_44.wav
# 成功轉換: wedding_45.wav
# 成功轉換: wedding_46.wav
# 成功轉換: wedding_47.wav
# 成功轉換: wedding_48.wav
# 成功轉換: wedding_49.wav
# 成功轉換: wedding_50.wav
# 成功轉換: wedding_51.wav
# 成功轉換: wedding_52.wav
# 成功轉換: wedding_53.wav
# 成功轉換: wedding_54.wav
# 成功轉換: wedding_55.wav
# 成功轉換: wedding_56.wav

# %%
# 刪除 MP4
dir = mp4_path
for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))
dir = wav_path
for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

# %%
'''
youtube_lists_url = ["https://youtube.com/playlist?list=PLNhzyV4NWnWNFiDSn-pSV7_Q0JSxsE7oW",
                    "https://youtube.com/playlist?list=PLNhzyV4NWnWMb2xL7XFoEb2PKjnJBE4Mb"]

classes = "occasion"
label = "wedding"
'''

'''
youtube_lists_url = ["https://youtube.com/playlist?list=PLNhzyV4NWnWNOo9Hr8cNNnJbXf15n_S4t",
                    "https://youtube.com/playlist?list=PLNhzyV4NWnWNesLmJl4ejgChZ22_a79L1"]

classes = "occasion"
label = "sports"
'''

'''
youtube_lists_url = ["https://youtube.com/playlist?list=PLNhzyV4NWnWM3-Sb3nHeklp5-DPO-TAeA",
                    "https://youtube.com/playlist?list=PLNhzyV4NWnWOGniKUy8l9XUv88Cr9u08l"]

classes = "occasion"
label = "seminar"
'''

'''
youtube_lists_url = ["https://youtube.com/playlist?list=PLNhzyV4NWnWMgPFavWl5Eo1btzhoFyQi6",
                    "https://youtube.com/playlist?list=PLNhzyV4NWnWMWh4Y-6MaVc_8YTbRZWQaI"]

classes = "occasion"
label = "graduation"
'''

'''
youtube_lists_url = ["https://youtube.com/playlist?list=PLNhzyV4NWnWNYLfx4d5OqKaX-D4nBtCMC",
                    "https://youtube.com/playlist?list=PLNhzyV4NWnWOKgnqsVm1imvH8IQlMQlc2"]

classes = "occasion"
label = "gathering"
'''

'''
youtube_lists_url = ["https://youtube.com/playlist?list=PLNhzyV4NWnWOR7GeDM314wsmLD4wI31NR",
                    "https://youtube.com/playlist?list=PLNhzyV4NWnWMGOhMHQ5iN2kHsZxQcbt_D"]

classes = "occasion"
label = "company"
'''

'''
youtube_lists_url = ["https://youtube.com/playlist?list=PLNhzyV4NWnWMaEezVzVs9bBe4En0MYqq0",
                    "https://youtube.com/playlist?list=PLNhzyV4NWnWPg906ZXTcB8zekuhkTxswK"]

classes = "occasion"
label = "coffee"
'''

'''
youtube_lists_url = ["https://youtube.com/playlist?list=PLNhzyV4NWnWNkxh5FK-AITO2R_3JGCbcr",
                    "https://youtube.com/playlist?list=PLNhzyV4NWnWMzmQlRL9iIQok-J0rR5fGS"]

classes = "occasion"
label = "awards"
'''
